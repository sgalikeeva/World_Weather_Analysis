# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key 

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations. CHANGE SIZE TO 2000 LATER.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_all = city_weather["weather"]
        city_desc = city_weather_all[0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chulym
# Processing Record 2 of Set 1 | sorong
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | ballina
# Processing Record 5 of Set 1 | corrales
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | porto novo
# Processing Record 9 of Set 1 | avera
# Processing Record 10 of Set 1 | ponta delgada
# Processing Record 11 of Set 1 | ati
# Processing Record 12 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 1 | ulaanbaatar
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | pekan
# Processing Record 17 of Set 1 | miri
# Processing Record 18 of Set 1 | katangli
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | rosarito
# Processing Record 22 of Set 1 | atbasar
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | tortoli
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | katha
# City not found. Skipping...
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | buala
# Processing Record 29 of Set 1 | ostrovnoy
# Processing Record 30 of Set 1 | te anau
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | hami
# Processing Record 34 of Set 1 | berlevag
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | malanje
# Processing Record 37 of Set 1 | port-cartier
# Processing Record 38 of Set 1 | kaihua
# Processing Record 39 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 1 | inhambane
# Processing Record 41 of Set 1 | zhanaozen
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | louisville
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | zverinogolovskoye
# Processing Record 3 of Set 2 | chimoio
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | omsukchan
# Processing Record 7 of Set 2 | thunder bay
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | oktyabrskiy
# Processing Record 11 of Set 2 | sawtell
# Processing Record 12 of Set 2 | geraldton
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | codrington
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | hirtshals
# Processing Record 17 of Set 2 | aksarka
# Processing Record 18 of Set 2 | nanakuli
# Processing Record 19 of Set 2 | kutum
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | doha
# Processing Record 22 of Set 2 | boyolangu
# Processing Record 23 of Set 2 | talaya
# Processing Record 24 of Set 2 | hongjiang
# Processing Record 25 of Set 2 | dalvik
# Processing Record 26 of Set 2 | henties bay
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | hay river
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | vestmanna
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | tifton
# Processing Record 35 of Set 2 | nouadhibou
# Processing Record 36 of Set 2 | batticaloa
# Processing Record 37 of Set 2 | sistranda
# Processing Record 38 of Set 2 | rikitea
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | nuuk
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | vila velha
# Processing Record 43 of Set 2 | olinda
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | santa maria
# Processing Record 47 of Set 2 | kosh-agach
# Processing Record 48 of Set 2 | pacific grove
# Processing Record 49 of Set 2 | talnakh
# Processing Record 50 of Set 2 | mackay
# Processing Record 1 of Set 3 | broken hill
# Processing Record 2 of Set 3 | de aar
# Processing Record 3 of Set 3 | mazamari
# Processing Record 4 of Set 3 | severouralsk
# Processing Record 5 of Set 3 | macas
# Processing Record 6 of Set 3 | uyuni
# Processing Record 7 of Set 3 | lindi
# Processing Record 8 of Set 3 | nioro
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 3 | tuatapere
# Processing Record 12 of Set 3 | barntrup
# Processing Record 13 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | currais novos
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | mayor pablo lagerenza
# Processing Record 18 of Set 3 | canitas
# City not found. Skipping...
# Processing Record 19 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 3 | atuona
# Processing Record 21 of Set 3 | yerbogachen
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | pevek
# Processing Record 24 of Set 3 | saint george
# Processing Record 25 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 3 | lorengau
# Processing Record 27 of Set 3 | aksu
# Processing Record 28 of Set 3 | kotra
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | tuktoyaktuk
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | halstenbek
# Processing Record 33 of Set 3 | bandarbeyla
# Processing Record 34 of Set 3 | ketchikan
# Processing Record 35 of Set 3 | krasnoshchekovo
# Processing Record 36 of Set 3 | gat
# Processing Record 37 of Set 3 | ashland
# Processing Record 38 of Set 3 | amapa
# Processing Record 39 of Set 3 | kavaratti
# Processing Record 40 of Set 3 | sterling
# Processing Record 41 of Set 3 | yuksekova
# Processing Record 42 of Set 3 | port hedland
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | azul
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | emerald
# Processing Record 48 of Set 3 | port hardy
# Processing Record 49 of Set 3 | padang
# Processing Record 50 of Set 3 | tiksi
# Processing Record 1 of Set 4 | andenes
# Processing Record 2 of Set 4 | wilhelmsburg
# Processing Record 3 of Set 4 | kununurra
# Processing Record 4 of Set 4 | new norfolk
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | tabuk
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | ginir
# Processing Record 9 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 4 | hosakote
# Processing Record 11 of Set 4 | basco
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | thompson
# Processing Record 14 of Set 4 | pidhorodna
# Processing Record 15 of Set 4 | arraial do cabo
# Processing Record 16 of Set 4 | grand gaube
# Processing Record 17 of Set 4 | bethel
# Processing Record 18 of Set 4 | aykhal
# Processing Record 19 of Set 4 | san patricio
# Processing Record 20 of Set 4 | grindavik
# Processing Record 21 of Set 4 | hermanus
# Processing Record 22 of Set 4 | cuamba
# Processing Record 23 of Set 4 | half moon bay
# Processing Record 24 of Set 4 | ucluelet
# Processing Record 25 of Set 4 | nagato
# Processing Record 26 of Set 4 | maltahohe
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record 29 of Set 4 | saldanha
# Processing Record 30 of Set 4 | rorvik
# Processing Record 31 of Set 4 | kushima
# Processing Record 32 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 4 | namyslow
# Processing Record 34 of Set 4 | chiungutwa
# Processing Record 35 of Set 4 | faanui
# Processing Record 36 of Set 4 | honiara
# Processing Record 37 of Set 4 | alyangula
# Processing Record 38 of Set 4 | quatre cocos
# Processing Record 39 of Set 4 | lieksa
# Processing Record 40 of Set 4 | sangar
# Processing Record 41 of Set 4 | cherskiy
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | stornoway
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 4 | kahului
# Processing Record 48 of Set 4 | gasa
# Processing Record 49 of Set 4 | kaka
# Processing Record 50 of Set 4 | lompoc
# Processing Record 1 of Set 5 | mbour
# Processing Record 2 of Set 5 | bar harbor
# Processing Record 3 of Set 5 | dryden
# Processing Record 4 of Set 5 | pali
# Processing Record 5 of Set 5 | meulaboh
# Processing Record 6 of Set 5 | vaini
# Processing Record 7 of Set 5 | kilrush
# Processing Record 8 of Set 5 | verkhoturye
# Processing Record 9 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 5 | desnogorsk
# Processing Record 11 of Set 5 | kamenka
# Processing Record 12 of Set 5 | bayir
# Processing Record 13 of Set 5 | sibu
# Processing Record 14 of Set 5 | piacabucu
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | muros
# Processing Record 17 of Set 5 | mounana
# Processing Record 18 of Set 5 | america dourada
# Processing Record 19 of Set 5 | genc
# Processing Record 20 of Set 5 | chokurdakh
# Processing Record 21 of Set 5 | manggar
# Processing Record 22 of Set 5 | sao jose da coroa grande
# Processing Record 23 of Set 5 | vilhena
# Processing Record 24 of Set 5 | umm lajj
# Processing Record 25 of Set 5 | igrim
# Processing Record 26 of Set 5 | atikokan
# Processing Record 27 of Set 5 | saint anthony
# Processing Record 28 of Set 5 | aginskoye
# Processing Record 29 of Set 5 | matara
# Processing Record 30 of Set 5 | saint-philippe
# Processing Record 31 of Set 5 | north bend
# Processing Record 32 of Set 5 | nurota
# Processing Record 33 of Set 5 | kigali
# Processing Record 34 of Set 5 | kesennuma
# City not found. Skipping...
# Processing Record 35 of Set 5 | lagoa
# Processing Record 36 of Set 5 | polovinnoye
# Processing Record 37 of Set 5 | okha
# Processing Record 38 of Set 5 | ilulissat
# Processing Record 39 of Set 5 | alofi
# Processing Record 40 of Set 5 | voh
# Processing Record 41 of Set 5 | jumla
# Processing Record 42 of Set 5 | inverell
# Processing Record 43 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 5 | deputatskiy
# Processing Record 45 of Set 5 | mount isa
# Processing Record 46 of Set 5 | srikakulam
# Processing Record 47 of Set 5 | tutoia
# Processing Record 48 of Set 5 | roebourne
# Processing Record 49 of Set 5 | hambantota
# Processing Record 50 of Set 5 | nerchinskiy zavod
# Processing Record 1 of Set 6 | liverpool
# Processing Record 2 of Set 6 | tura
# Processing Record 3 of Set 6 | mataura
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | nikolskoye
# Processing Record 6 of Set 6 | sungairaya
# Processing Record 7 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 6 | risti
# Processing Record 9 of Set 6 | iranshahr
# Processing Record 10 of Set 6 | katsuura
# Processing Record 11 of Set 6 | hays
# Processing Record 12 of Set 6 | milingimbi
# City not found. Skipping...
# Processing Record 13 of Set 6 | miyako
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | mahabad
# Processing Record 16 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 6 | bayan
# Processing Record 18 of Set 6 | grand-santi
# Processing Record 19 of Set 6 | sao filipe
# Processing Record 20 of Set 6 | roma
# Processing Record 21 of Set 6 | castro
# Processing Record 22 of Set 6 | boa vista
# Processing Record 23 of Set 6 | auriflama
# Processing Record 24 of Set 6 | sao geraldo do araguaia
# Processing Record 25 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 6 | cap-aux-meules
# Processing Record 28 of Set 6 | constitucion
# Processing Record 29 of Set 6 | kanpur
# Processing Record 30 of Set 6 | ahipara
# Processing Record 31 of Set 6 | belyy yar
# Processing Record 32 of Set 6 | atambua
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | aklavik
# Processing Record 35 of Set 6 | pasighat
# Processing Record 36 of Set 6 | dzerzhinsk
# Processing Record 37 of Set 6 | port-gentil
# Processing Record 38 of Set 6 | solnechnyy
# Processing Record 39 of Set 6 | udachnyy
# Processing Record 40 of Set 6 | moussoro
# Processing Record 41 of Set 6 | aitape
# Processing Record 42 of Set 6 | iracoubo
# Processing Record 43 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 6 | toamua
# City not found. Skipping...
# Processing Record 45 of Set 6 | zambezi
# Processing Record 46 of Set 6 | dali
# Processing Record 47 of Set 6 | bubaque
# Processing Record 48 of Set 6 | sorland
# Processing Record 49 of Set 6 | novonikolsk
# Processing Record 50 of Set 6 | praia da vitoria
# Processing Record 1 of Set 7 | margate
# Processing Record 2 of Set 7 | vostok
# Processing Record 3 of Set 7 | haines junction
# Processing Record 4 of Set 7 | nome
# Processing Record 5 of Set 7 | tsurugi
# Processing Record 6 of Set 7 | vila franca do campo
# Processing Record 7 of Set 7 | luderitz
# Processing Record 8 of Set 7 | christchurch
# Processing Record 9 of Set 7 | moree
# Processing Record 10 of Set 7 | college
# Processing Record 11 of Set 7 | sisimiut
# Processing Record 12 of Set 7 | narsaq
# Processing Record 13 of Set 7 | eureka
# Processing Record 14 of Set 7 | kerouane
# Processing Record 15 of Set 7 | innisfail
# Processing Record 16 of Set 7 | kourou
# Processing Record 17 of Set 7 | chernyshevskiy
# Processing Record 18 of Set 7 | storm lake
# Processing Record 19 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 7 | abha
# Processing Record 21 of Set 7 | bodden town
# Processing Record 22 of Set 7 | totness
# Processing Record 23 of Set 7 | esperance
# Processing Record 24 of Set 7 | ribeira brava
# Processing Record 25 of Set 7 | kondinskoye
# Processing Record 26 of Set 7 | kudahuvadhoo
# Processing Record 27 of Set 7 | moa
# Processing Record 28 of Set 7 | yulara
# Processing Record 29 of Set 7 | rongcheng
# Processing Record 30 of Set 7 | baoying
# Processing Record 31 of Set 7 | mahibadhoo
# Processing Record 32 of Set 7 | tual
# Processing Record 33 of Set 7 | abu kamal
# Processing Record 34 of Set 7 | lar
# Processing Record 35 of Set 7 | pudozh
# Processing Record 36 of Set 7 | namtsy
# Processing Record 37 of Set 7 | skjervoy
# Processing Record 38 of Set 7 | ileza
# Processing Record 39 of Set 7 | yabelo
# Processing Record 40 of Set 7 | los llanos de aridane
# Processing Record 41 of Set 7 | baculin
# Processing Record 42 of Set 7 | tilichiki
# Processing Record 43 of Set 7 | nanortalik
# Processing Record 44 of Set 7 | raymondville
# Processing Record 45 of Set 7 | antofagasta
# Processing Record 46 of Set 7 | roald
# Processing Record 47 of Set 7 | kongsberg
# Processing Record 48 of Set 7 | rosetown
# Processing Record 49 of Set 7 | caravelas
# Processing Record 50 of Set 7 | plettenberg bay
# Processing Record 1 of Set 8 | salamiyah
# Processing Record 2 of Set 8 | bonga
# Processing Record 3 of Set 8 | atar
# Processing Record 4 of Set 8 | muisne
# Processing Record 5 of Set 8 | poum
# Processing Record 6 of Set 8 | krasnyy luch
# Processing Record 7 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 8 | davila
# Processing Record 9 of Set 8 | luanda
# Processing Record 10 of Set 8 | apricena
# Processing Record 11 of Set 8 | newport
# Processing Record 12 of Set 8 | changji
# Processing Record 13 of Set 8 | pacifica
# Processing Record 14 of Set 8 | byron bay
# Processing Record 15 of Set 8 | aras
# Processing Record 16 of Set 8 | pergamino
# Processing Record 17 of Set 8 | manokwari
# Processing Record 18 of Set 8 | jalingo
# Processing Record 19 of Set 8 | pisco
# Processing Record 20 of Set 8 | traverse city
# Processing Record 21 of Set 8 | fryanovo
# Processing Record 22 of Set 8 | tautira
# Processing Record 23 of Set 8 | arman
# Processing Record 24 of Set 8 | hede
# Processing Record 25 of Set 8 | tiznit
# Processing Record 26 of Set 8 | karaton
# Processing Record 27 of Set 8 | nantucket
# Processing Record 28 of Set 8 | nobeoka
# Processing Record 29 of Set 8 | tiarei
# Processing Record 30 of Set 8 | beloha
# Processing Record 31 of Set 8 | chokwe
# Processing Record 32 of Set 8 | mouzouras
# Processing Record 33 of Set 8 | palmer
# Processing Record 34 of Set 8 | cabra
# Processing Record 35 of Set 8 | moron
# Processing Record 36 of Set 8 | ambilobe
# Processing Record 37 of Set 8 | dembi dolo
# Processing Record 38 of Set 8 | khvoynaya
# Processing Record 39 of Set 8 | uniontown
# Processing Record 40 of Set 8 | portland
# Processing Record 41 of Set 8 | belaya gora
# Processing Record 42 of Set 8 | lufilufi
# Processing Record 43 of Set 8 | mercedes
# Processing Record 44 of Set 8 | ola
# Processing Record 45 of Set 8 | denpasar
# Processing Record 46 of Set 8 | samarai
# Processing Record 47 of Set 8 | lazarev
# Processing Record 48 of Set 8 | petropavl
# Processing Record 49 of Set 8 | hrodna
# Processing Record 50 of Set 8 | chapais
# Processing Record 1 of Set 9 | cukai
# Processing Record 2 of Set 9 | richards bay
# Processing Record 3 of Set 9 | cabo san lucas
# Processing Record 4 of Set 9 | laguna
# Processing Record 5 of Set 9 | jawhar
# Processing Record 6 of Set 9 | manbij
# Processing Record 7 of Set 9 | mount gambier
# Processing Record 8 of Set 9 | hammerfest
# Processing Record 9 of Set 9 | canyon
# Processing Record 10 of Set 9 | cilegon
# Processing Record 11 of Set 9 | mani
# Processing Record 12 of Set 9 | fairbanks
# Processing Record 13 of Set 9 | aasiaat
# Processing Record 14 of Set 9 | rabo de peixe
# Processing Record 15 of Set 9 | canete
# Processing Record 16 of Set 9 | kantilo
# Processing Record 17 of Set 9 | baghdad
# Processing Record 18 of Set 9 | severo-kurilsk
# Processing Record 19 of Set 9 | penzance
# Processing Record 20 of Set 9 | tauranga
# Processing Record 21 of Set 9 | skovde
# City not found. Skipping...
# Processing Record 22 of Set 9 | lodja
# Processing Record 23 of Set 9 | lavrentiya
# Processing Record 24 of Set 9 | leningradskiy
# Processing Record 25 of Set 9 | gallup
# Processing Record 26 of Set 9 | sibolga
# Processing Record 27 of Set 9 | matamoros
# Processing Record 28 of Set 9 | clyde river
# Processing Record 29 of Set 9 | oranjestad
# Processing Record 30 of Set 9 | fort nelson
# Processing Record 31 of Set 9 | dalnegorsk
# Processing Record 32 of Set 9 | mana
# Processing Record 33 of Set 9 | hofn
# Processing Record 34 of Set 9 | beringovskiy
# Processing Record 35 of Set 9 | burica
# City not found. Skipping...
# Processing Record 36 of Set 9 | goderich
# Processing Record 37 of Set 9 | alice springs
# Processing Record 38 of Set 9 | moissala
# Processing Record 39 of Set 9 | valle de allende
# Processing Record 40 of Set 9 | komsomolskiy
# Processing Record 41 of Set 9 | maniitsoq
# Processing Record 42 of Set 9 | sitka
# Processing Record 43 of Set 9 | bathsheba
# Processing Record 44 of Set 9 | thyolo
# Processing Record 45 of Set 9 | snyder
# Processing Record 46 of Set 9 | ulladulla
# Processing Record 47 of Set 9 | hithadhoo
# Processing Record 48 of Set 9 | bacong
# Processing Record 49 of Set 9 | natal
# Processing Record 50 of Set 9 | swellendam
# Processing Record 1 of Set 10 | solwezi
# Processing Record 2 of Set 10 | monrovia
# Processing Record 3 of Set 10 | brae
# Processing Record 4 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 10 | dajal
# Processing Record 6 of Set 10 | mitu
# Processing Record 7 of Set 10 | seybaplaya
# Processing Record 8 of Set 10 | rakhiv
# Processing Record 9 of Set 10 | halifax
# Processing Record 10 of Set 10 | najran
# Processing Record 11 of Set 10 | gamba
# Processing Record 12 of Set 10 | gumdag
# Processing Record 13 of Set 10 | sioux lookout
# Processing Record 14 of Set 10 | fene
# Processing Record 15 of Set 10 | la ronge
# Processing Record 16 of Set 10 | concarneau
# Processing Record 17 of Set 10 | kharp
# Processing Record 18 of Set 10 | alta floresta
# Processing Record 19 of Set 10 | yumen
# Processing Record 20 of Set 10 | thilogne
# City not found. Skipping...
# Processing Record 21 of Set 10 | krasnoselkup
# Processing Record 22 of Set 10 | mayumba
# Processing Record 23 of Set 10 | prieska
# Processing Record 24 of Set 10 | vung tau
# Processing Record 25 of Set 10 | challapata
# Processing Record 26 of Set 10 | coquimbo
# Processing Record 27 of Set 10 | bereda
# Processing Record 28 of Set 10 | siderno
# Processing Record 29 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 10 | touros
# Processing Record 31 of Set 10 | celestun
# Processing Record 32 of Set 10 | nelson bay
# Processing Record 33 of Set 10 | shahpura
# Processing Record 34 of Set 10 | bukachacha
# Processing Record 35 of Set 10 | tha mai
# Processing Record 36 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 37 of Set 10 | port blair
# Processing Record 38 of Set 10 | san cristobal
# Processing Record 39 of Set 10 | akyab
# Processing Record 40 of Set 10 | smithers
# Processing Record 41 of Set 10 | socorro
# Processing Record 42 of Set 10 | vestmannaeyjar
# Processing Record 43 of Set 10 | port macquarie
# Processing Record 44 of Set 10 | verkhnevilyuysk
# Processing Record 45 of Set 10 | taltal
# Processing Record 46 of Set 10 | brodnica
# Processing Record 47 of Set 10 | kysyl-syr
# Processing Record 48 of Set 10 | galveston
# Processing Record 49 of Set 10 | birjand
# Processing Record 50 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 1 of Set 11 | altay
# Processing Record 2 of Set 11 | hoquiam
# Processing Record 3 of Set 11 | orsha
# Processing Record 4 of Set 11 | zherdevka
# Processing Record 5 of Set 11 | kuytun
# Processing Record 6 of Set 11 | glenwood springs
# Processing Record 7 of Set 11 | varda
# Processing Record 8 of Set 11 | gaspe
# Processing Record 9 of Set 11 | sinnamary
# Processing Record 10 of Set 11 | vaitape
# Processing Record 11 of Set 11 | hirara
# Processing Record 12 of Set 11 | kasongo-lunda
# Processing Record 13 of Set 11 | hovd
# Processing Record 14 of Set 11 | petrolandia
# City not found. Skipping...
# Processing Record 15 of Set 11 | angoche
# Processing Record 16 of Set 11 | saint-francois
# Processing Record 17 of Set 11 | ambon
# Processing Record 18 of Set 11 | moiyabana
# City not found. Skipping...
# Processing Record 19 of Set 11 | nemuro
# Processing Record 20 of Set 11 | dothan
# Processing Record 21 of Set 11 | paamiut
# Processing Record 22 of Set 11 | corinto
# Processing Record 23 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 11 | changping
# Processing Record 25 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 11 | homer
# Processing Record 27 of Set 11 | nadym
# Processing Record 28 of Set 11 | bibiani
# Processing Record 29 of Set 11 | havelock
# Processing Record 30 of Set 11 | bonnyville
# Processing Record 31 of Set 11 | ancud
# Processing Record 32 of Set 11 | kavieng
# Processing Record 33 of Set 11 | merritt island
# Processing Record 34 of Set 11 | shahrud
# Processing Record 35 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 11 | lashio
# Processing Record 37 of Set 11 | sur
# Processing Record 38 of Set 11 | ozu
# Processing Record 39 of Set 11 | pervomayskiy
# Processing Record 40 of Set 11 | imeni babushkina
# Processing Record 41 of Set 11 | nioaque
# Processing Record 42 of Set 11 | baruun-urt
# Processing Record 43 of Set 11 | mahajanga
# Processing Record 44 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 45 of Set 11 | san quintin
# Processing Record 46 of Set 11 | buenos aires
# Processing Record 47 of Set 11 | kuryk
# Processing Record 48 of Set 11 | pavino
# Processing Record 49 of Set 11 | iqaluit
# Processing Record 50 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 12 | bima
# Processing Record 2 of Set 12 | hualmay
# Processing Record 3 of Set 12 | general roca
# Processing Record 4 of Set 12 | rawson
# Processing Record 5 of Set 12 | nicoya
# Processing Record 6 of Set 12 | olafsvik
# Processing Record 7 of Set 12 | pakokku
# Processing Record 8 of Set 12 | arys
# Processing Record 9 of Set 12 | rovira
# Processing Record 10 of Set 12 | paka
# Processing Record 11 of Set 12 | puerto del rosario
# Processing Record 12 of Set 12 | galle
# Processing Record 13 of Set 12 | axim
# Processing Record 14 of Set 12 | verkhovazhye
# Processing Record 15 of Set 12 | monte alegre
# Processing Record 16 of Set 12 | kalmunai
# Processing Record 17 of Set 12 | belomorsk
# Processing Record 18 of Set 12 | egvekinot
# Processing Record 19 of Set 12 | the valley
# Processing Record 20 of Set 12 | shimoda
# Processing Record 21 of Set 12 | uarini
# Processing Record 22 of Set 12 | westport
# Processing Record 23 of Set 12 | billings
# Processing Record 24 of Set 12 | havoysund
# Processing Record 25 of Set 12 | williams lake
# Processing Record 26 of Set 12 | contamana
# Processing Record 27 of Set 12 | pangnirtung
# Processing Record 28 of Set 12 | nisia floresta
# Processing Record 29 of Set 12 | thung song
# Processing Record 30 of Set 12 | lorient
# Processing Record 31 of Set 12 | xai-xai
# Processing Record 32 of Set 12 | ishigaki
# Processing Record 33 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 12 | jalu
# Processing Record 35 of Set 12 | channel-port aux basques
# Processing Record 36 of Set 12 | aliaga
# Processing Record 37 of Set 12 | ust-uda
# Processing Record 38 of Set 12 | praia
# Processing Record 39 of Set 12 | saint-joseph
# Processing Record 40 of Set 12 | evensk
# Processing Record 41 of Set 12 | kamaishi
# Processing Record 42 of Set 12 | prabumulih
# Processing Record 43 of Set 12 | lata
# Processing Record 44 of Set 12 | humaita
# Processing Record 45 of Set 12 | coahuayana
# Processing Record 46 of Set 12 | cayenne
# Processing Record 47 of Set 12 | banda aceh
# Processing Record 48 of Set 12 | husavik
# Processing Record 49 of Set 12 | kumano
# Processing Record 50 of Set 12 | dawlatabad
# Processing Record 1 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 13 | alingsas
# Processing Record 3 of Set 13 | chernogorsk
# Processing Record 4 of Set 13 | duz
# City not found. Skipping...
# Processing Record 5 of Set 13 | charagua
# Processing Record 6 of Set 13 | seoul
# Processing Record 7 of Set 13 | griffith
# Processing Record 8 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 9 of Set 13 | marrakesh
# Processing Record 10 of Set 13 | kupang
# Processing Record 11 of Set 13 | rio grande
# Processing Record 12 of Set 13 | carman
# Processing Record 13 of Set 13 | bilma
# Processing Record 14 of Set 13 | tabou
# Processing Record 15 of Set 13 | chauk
# Processing Record 16 of Set 13 | irbit
# Processing Record 17 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 13 | takaka
# Processing Record 19 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 13 | bilibino
# Processing Record 21 of Set 13 | hot springs
# Processing Record 22 of Set 13 | santa isabel
# Processing Record 23 of Set 13 | knysna
# Processing Record 24 of Set 13 | korhogo
# Processing Record 25 of Set 13 | bashtanka
# Processing Record 26 of Set 13 | concepcion del uruguay
# Processing Record 27 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 28 of Set 13 | itoman
# Processing Record 29 of Set 13 | nordhorn
# Processing Record 30 of Set 13 | asosa
# Processing Record 31 of Set 13 | tarauaca
# Processing Record 32 of Set 13 | santa rosa
# Processing Record 33 of Set 13 | galdar
# Processing Record 34 of Set 13 | little rock
# Processing Record 35 of Set 13 | koslan
# Processing Record 36 of Set 13 | berezovyy
# Processing Record 37 of Set 13 | madang
# Processing Record 38 of Set 13 | loreto
# Processing Record 39 of Set 13 | talara
# Processing Record 40 of Set 13 | terrace bay
# Processing Record 41 of Set 13 | velikiy ustyug
# Processing Record 42 of Set 13 | nkoteng
# Processing Record 43 of Set 13 | vrchlabi
# Processing Record 44 of Set 13 | massaguet
# Processing Record 45 of Set 13 | black forest
# Processing Record 46 of Set 13 | kyzyl-suu
# Processing Record 47 of Set 13 | labuhan
# Processing Record 48 of Set 13 | pula
# Processing Record 49 of Set 13 | dwarka
# Processing Record 50 of Set 13 | ahuimanu
# Processing Record 1 of Set 14 | srivardhan
# Processing Record 2 of Set 14 | yining
# Processing Record 3 of Set 14 | koumac
# Processing Record 4 of Set 14 | salinas
# Processing Record 5 of Set 14 | mongar
# Processing Record 6 of Set 14 | nalut
# Processing Record 7 of Set 14 | samandag
# Processing Record 8 of Set 14 | dallas
# Processing Record 9 of Set 14 | ipora
# Processing Record 10 of Set 14 | khani
# Processing Record 11 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 14 | chirongui
# Processing Record 14 of Set 14 | dodge city
# Processing Record 15 of Set 14 | karabuk
# Processing Record 16 of Set 14 | marzuq
# Processing Record 17 of Set 14 | tooele
# Processing Record 18 of Set 14 | maumere
# Processing Record 19 of Set 14 | manadhoo
# Processing Record 20 of Set 14 | kuala krai
# City not found. Skipping...
# Processing Record 21 of Set 14 | ejutla de crespo
# Processing Record 22 of Set 14 | acapulco
# Processing Record 23 of Set 14 | malakal
# Processing Record 24 of Set 14 | hajnowka
# Processing Record 25 of Set 14 | taoudenni
# Processing Record 26 of Set 14 | hearst
# Processing Record 27 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 14 | clearlake
# Processing Record 29 of Set 14 | nishihara
# Processing Record 30 of Set 14 | vanderhoof
# Processing Record 31 of Set 14 | tokoroa
# Processing Record 32 of Set 14 | tchibanga
# Processing Record 33 of Set 14 | ewa beach
# Processing Record 34 of Set 14 | neokaisaria
# City not found. Skipping...
# Processing Record 35 of Set 14 | srednekolymsk
# Processing Record 36 of Set 14 | kapoeta
# Processing Record 37 of Set 14 | vilyuysk
# Processing Record 38 of Set 14 | vynohradove
# Processing Record 39 of Set 14 | keuruu
# Processing Record 40 of Set 14 | fayaoue
# Processing Record 41 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 14 | vardo
# Processing Record 43 of Set 14 | paso de carrasco
# Processing Record 44 of Set 14 | kaseda
# Processing Record 45 of Set 14 | shirokiy
# Processing Record 46 of Set 14 | kloulklubed
# Processing Record 47 of Set 14 | tarko-sale
# Processing Record 48 of Set 14 | uruacu
# Processing Record 49 of Set 14 | ndioum
# Processing Record 50 of Set 14 | niort
# Processing Record 1 of Set 15 | san juan
# Processing Record 2 of Set 15 | juneau
# Processing Record 3 of Set 15 | eitorf
# Processing Record 4 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 5 of Set 15 | tulagi
# Processing Record 6 of Set 15 | price
# Processing Record 7 of Set 15 | pirayu
# Processing Record 8 of Set 15 | jutai
# Processing Record 9 of Set 15 | klaksvik
# Processing Record 10 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 11 of Set 15 | baia
# Processing Record 12 of Set 15 | turayf
# Processing Record 13 of Set 15 | zeya
# Processing Record 14 of Set 15 | mosquera
# Processing Record 15 of Set 15 | san lorenzo
# Processing Record 16 of Set 15 | sola
# Processing Record 17 of Set 15 | ludza
# Processing Record 18 of Set 15 | novo aripuana
# Processing Record 19 of Set 15 | khandyga
# Processing Record 20 of Set 15 | mizdah
# Processing Record 21 of Set 15 | namatanai
# Processing Record 22 of Set 15 | vao
# Processing Record 23 of Set 15 | minsk
# Processing Record 24 of Set 15 | urucara
# Processing Record 25 of Set 15 | wurzen
# Processing Record 26 of Set 15 | chardara
# Processing Record 27 of Set 15 | prince rupert
# Processing Record 28 of Set 15 | viedma
# Processing Record 29 of Set 15 | bowen
# Processing Record 30 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 15 | assiniboia
# Processing Record 32 of Set 15 | elko
# Processing Record 33 of Set 15 | datong
# Processing Record 34 of Set 15 | plouzane
# Processing Record 35 of Set 15 | tessalit
# Processing Record 36 of Set 15 | elmira
# Processing Record 37 of Set 15 | verkhnedneprovskiy
# Processing Record 38 of Set 15 | dangriga
# Processing Record 39 of Set 15 | limot
# Processing Record 40 of Set 15 | mitsamiouli
# Processing Record 41 of Set 15 | greystones
# Processing Record 42 of Set 15 | mabama
# Processing Record 43 of Set 15 | bardiyah
# Processing Record 44 of Set 15 | mayo
# Processing Record 45 of Set 15 | mizan teferi
# Processing Record 46 of Set 15 | burnie
# Processing Record 47 of Set 15 | martapura
# Processing Record 48 of Set 15 | lamu
# Processing Record 49 of Set 15 | biak
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Chulym      RU  55.0997   80.9572    -18.33       100         100
# 1         Sorong      ID  -0.8833  131.2500     84.52        71          97
# 2      Busselton      AU -33.6500  115.3333     73.04        42           0
# 3        Ballina      AU -28.8667  153.5667     80.78        68          75
# 4       Corrales      US  35.2378 -106.6067     39.88        60           1
# 5   Kruisfontein      ZA -34.0033   24.7314     64.89        95          83
# 6          Bluff      NZ -46.6000  168.3333     58.80        58          48
# 7     Porto Novo      BJ   6.4965    2.6036     76.82        85           0
# 8          Avera      US  33.1940  -82.5271     46.71        72          33
# 9  Ponta Delgada      PT  37.7333  -25.6667     58.50        72          20
#
#    Wind Speed Current Description                 Date
# 0        3.69     overcast clouds  2022-01-27 01:47:23
# 1        7.87     overcast clouds  2022-01-27 01:42:50
# 2        9.71           clear sky  2022-01-27 01:47:24
# 3       10.36       broken clouds  2022-01-27 01:47:24
# 4        1.99           clear sky  2022-01-27 01:47:25
# 5        1.95       broken clouds  2022-01-27 01:47:25
# 6       12.17    scattered clouds  2022-01-27 01:47:25
# 7        2.15           clear sky  2022-01-27 01:47:26
# 8        8.81    scattered clouds  2022-01-27 01:47:26
# 9       11.50          few clouds  2022-01-27 01:47:27

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
